# %% [markdown]
# from pickle import load, dump

# %%
from pickle import load

# %%
from joblib import load
import numpy as np
import matplotlib.pyplot as plt

# %%
from skimage.io import imread

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
data = load('fruit.joblib')

# %%
img_data = []
for i in data['datas']:
    img = np.array(i).flatten()
    img_data.append(img)

# %%
len(img_data)
# Out:
# 634

# %%
len(data['labels'])
# Out:
# 634

# %%
x_train, x_test, y_train, y_test = train_test_split(img_data, np.array(data['labels']), test_size=0.2 )

# %%
y_test[0]
# Out:
# 'Banana Red'

# %%
model = SVC(C=1, kernel='poly',gamma='auto')

# %%
model.fit(x_train, y_train)
# Out:
# SVC(C=1, gamma='auto', kernel='poly')

# %%
model.predict([x_test[0]])
# Out:
# array(['Banana Red'], dtype='<U14')

# %%
import cv2

# %%
# img = 'Fruit-Images-Dataset-master/Training/Apple Braeburn/2_100.jpg'
img = 'Fruit-Images-Dataset-master\\Test\\Blueberry\\r_213_100.jpg'
img = imread(img)

# %%
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# img = np.array(data['datas'][390]).flatten()
img = np.array(img).flatten()

# %%
y_pred =model.predict([img])

# %%
y_pred
# Out:
# array(['Blueberry'], dtype='<U14')
